# %%
#Imports
import PyPDF2
from pikepdf import Pdf

# %%
#Chooose file path
fp=r'C:\Users\Andrew Chan\OneDrive\Documents\中醫食療概念\課程筆記_880168_中醫食療概念_Internet Mode_PW.pdf'

# %%
#Break password with PikePDF
with Pdf.open(fp) as pdf:
    pdf.save('output.pdf')

# %%
#Open file
with open('output.pdf',mode='rb') as f:
    reader=PyPDF2.PdfFileReader(f)
    if reader.isEncrypted:
        reader.decrypt('')
    page=reader.getPage(0)
    print(page.extractText())
# Out:
#
#
# ZZI³
#
#
#
#
# 880168_
# ˛ÕaSh⁄Eê9*/š
#
# iA=×˛Õ5/(Ï+ +°
#
#
# Page
# 1
#
# of
# 4
#
#
# 8
# 80168
#
# ˛ÕaSh⁄Eê9*/š
#
#
#
#
#
#
# 6ÔZZI³YÕ
# 6±
#
# 3
#
# p»5’&ÐYý˚Ø+ $›F,+ Oz_Ú.N#r+µ+ Iy˛óC®Y‰
# + $›g°2±
# ˜Œ
#
# p»
#
# &Ð
# 3x
# ˚L
#
# /4p»+¶-Ó
# ˛¨QÔ6«&Ð
#
# 4
#
# 6
# 5Ç6Ç
# +41¸2!4áp»˛Î+¯-ı2!4á
#
# @b`' õ&‹`šp».¢[˘+ $›&Ð3x˚L
#
#
#
#
#
# /mg°
# !¿5¶+ $›){#µ
#
#
#
#
# p»
#
#
#
#
# ` [(
#
# F,+ $›p»
# "†/m
# _Ë#´˛¨˜˛+l&ƒp»
#
#
#
#
# ` [(
# MZ˛²9É.·
# F,+ $›p»
# ˛¨
# ˜³:<7ðp»:<7ð(Ï+·˛µ#Š]-_ö
# 1MB
# p»
# p»˛Î˛²^±+ Oz.˙#Ÿp»/ý
# ˛µ
#
#
#
# DÛZs
#
# )*+ $›&‹B!!Í#G&‹
#
# (
# )*DÇEmf−=×-“Jñ
# )
# f¨.ž6Ç
# 3x
# ˚Lp»#Š5d5“6Ç!õ6¨
# +¹
# 3
# (Ñ#¹ZZI³LìDÛZs_N<}pł
# ˚“
# f£`š
# p·
# scs
# -
# deu@cuhk.edu.hk
# p¸
# 1¾`š
# p·
# &Ø&èpÉ
# $(>®$`_û"ÿ
# 39
#
# 6
# 9»
#
#
#
#
# p¸
# #¹
# ZZI³
# LìDÛZs
# p»˛Î!¿5¶pÉ
# i
# p¸
# + $›){#µpÊ
# ii
# p¸
# + $›M’pÊ
# iii
# p¸
# ZZI³M’pÊ
# iv
# p¸
# ZZI³#µIÙpÊ
# v
# p¸
#
# vi
# p¸
# .ž6Ç#G
# ;w:ÉDÛZs2±DÛZs#G&‹6¨(Â#™eø.ž6Ç
# 14
# (Ñ
#
#
# Zñ6€
#
# + $›
#
# ZZI³
# /4
# p»˛Î
# &Ð6¨+¹
# 70%
# p»˜g
# #Š5dZZI³
# DÛZs
# p»;w.ÝZñ6€4Þ\c
#
# $50
# p»p»
#
#
#
# iA=×˛Õ5/F,+ WûZH˜›Y);êp»
# ˛Î&\
# .·F,
# 2,b¬
# _¸
# #“#“*ø2,b¬1¾
# 5×
#
#
# +a
# O´
# <:6±
# Yã5¶\o5A˜.>8p»
# #˙
# #Š9s
# + $›
# )*Y).½DÐ˚~˚b˛ó5/J‹1¾Z~nƒp»Zs
# ˚“
#
# 9ÁHâ
# ˛ÎYã5¶
